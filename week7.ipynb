# %%
import pandas as pd
import numpy as np

people = pd.read_excel('PeopleData.xlsx', sheet_name = 'People')
location = pd.read_excel('PeopleData.xlsx', sheet_name = 'Location')
leader = pd.read_excel('PeopleData.xlsx', sheet_name = 'Leaders')
date = pd.read_excel('PeopleData.xlsx', sheet_name = 'Date Dim')
goal = pd.read_excel('PeopleData.xlsx', sheet_name = 'Goals')

# %%
df1 = pd.merge(people, leader, left_on = 'Leader 1', right_on = 'id', how = 'inner')
df1
# Out:
#      id_x first_name_x last_name_x  Leader 1 Location ID  id_y first_name_y  \
# 0       4        Fleur      Garnam         1         ABC     1        Kylie
# 1      10      Leanora      Beaver         1         ABC     1        Kylie
# 2      11      Zabrina      Cranke         1         ABC     1        Kylie
# 3      12        Berny    Matysiak         1         ABC     1        Kylie
# 4      22        Grace      Wyrall         1         ABC     1        Kylie
# ..    ...          ...         ...       ...         ...   ...          ...
# 130    86         Kiel    Longmate         9         JKL     9      Octavia
# 131    88       Fredek     Maltman         9         JKL     9      Octavia
# 132   104       Bendix        Beer         9         JKL     9      Octavia
# 133   122        Fanya      Frunks         9         JKL     9      Octavia
# 134   126        Ringo     Blizard         9         JKL     9      Octavia
#
#     last_name_y
# 0       Howroyd
# 1       Howroyd
# ...

# %%
df1['Agent Name'] = df1['last_name_x'] + ', ' + df1['first_name_x']
df1
# Out:
#      id_x first_name_x last_name_x  Leader 1 Location ID  id_y first_name_y  \
# 0       4        Fleur      Garnam         1         ABC     1        Kylie
# 1      10      Leanora      Beaver         1         ABC     1        Kylie
# 2      11      Zabrina      Cranke         1         ABC     1        Kylie
# 3      12        Berny    Matysiak         1         ABC     1        Kylie
# 4      22        Grace      Wyrall         1         ABC     1        Kylie
# ..    ...          ...         ...       ...         ...   ...          ...
# 130    86         Kiel    Longmate         9         JKL     9      Octavia
# 131    88       Fredek     Maltman         9         JKL     9      Octavia
# 132   104       Bendix        Beer         9         JKL     9      Octavia
# 133   122        Fanya      Frunks         9         JKL     9      Octavia
# 134   126        Ringo     Blizard         9         JKL     9      Octavia
#
#     last_name_y       Agent Name
# ...

# %%
df1['Leader Name'] = df1['last_name_y'] + ', ' + df1['first_name_y']
df1
# Out:
#      id_x first_name_x last_name_x  Leader 1 Location ID  id_y first_name_y  \
# 0       4        Fleur      Garnam         1         ABC     1        Kylie
# 1      10      Leanora      Beaver         1         ABC     1        Kylie
# 2      11      Zabrina      Cranke         1         ABC     1        Kylie
# 3      12        Berny    Matysiak         1         ABC     1        Kylie
# 4      22        Grace      Wyrall         1         ABC     1        Kylie
# ..    ...          ...         ...       ...         ...   ...          ...
# 130    86         Kiel    Longmate         9         JKL     9      Octavia
# 131    88       Fredek     Maltman         9         JKL     9      Octavia
# 132   104       Bendix        Beer         9         JKL     9      Octavia
# 133   122        Fanya      Frunks         9         JKL     9      Octavia
# 134   126        Ringo     Blizard         9         JKL     9      Octavia
#
#     last_name_y       Agent Name         Leader Name
# ...

# %%
df1 = df1.drop(columns = ['first_name_x','first_name_y','last_name_x','last_name_y'], axis = 1)
df1
# Out:
#      id_x  Leader 1 Location ID  id_y       Agent Name         Leader Name
# 0       4         1         ABC     1    Garnam, Fleur      Howroyd, Kylie
# 1      10         1         ABC     1  Beaver, Leanora      Howroyd, Kylie
# 2      11         1         ABC     1  Cranke, Zabrina      Howroyd, Kylie
# 3      12         1         ABC     1  Matysiak, Berny      Howroyd, Kylie
# 4      22         1         ABC     1    Wyrall, Grace      Howroyd, Kylie
# ..    ...       ...         ...   ...              ...                 ...
# 130    86         9         JKL     9   Longmate, Kiel  Waterfall, Octavia
# 131    88         9         JKL     9  Maltman, Fredek  Waterfall, Octavia
# 132   104         9         JKL     9     Beer, Bendix  Waterfall, Octavia
# 133   122         9         JKL     9    Frunks, Fanya  Waterfall, Octavia
# 134   126         9         JKL     9   Blizard, Ringo  Waterfall, Octavia
#
# [135 rows x 6 columns]

# %%
df1 = pd.merge(df1, location , on = 'Location ID' , how = 'inner')
df1
# Out:
#      id_x  Leader 1 Location ID  id_y       Agent Name         Leader Name  \
# 0       4         1         ABC     1    Garnam, Fleur      Howroyd, Kylie
# 1      10         1         ABC     1  Beaver, Leanora      Howroyd, Kylie
# 2      11         1         ABC     1  Cranke, Zabrina      Howroyd, Kylie
# 3      12         1         ABC     1  Matysiak, Berny      Howroyd, Kylie
# 4      22         1         ABC     1    Wyrall, Grace      Howroyd, Kylie
# ..    ...       ...         ...   ...              ...                 ...
# 130    86         9         JKL     9   Longmate, Kiel  Waterfall, Octavia
# 131    88         9         JKL     9  Maltman, Fredek  Waterfall, Octavia
# 132   104         9         JKL     9     Beer, Bendix  Waterfall, Octavia
# 133   122         9         JKL     9    Frunks, Fanya  Waterfall, Octavia
# 134   126         9         JKL     9   Blizard, Ringo  Waterfall, Octavia
#
#      Location
# 0    Margaree
# 1    Margaree
# 2    Margaree
# ...

# %%
df1 = df1.rename(columns={'id_x':'id'})
df1 = df1.drop(columns = 'id_y', axis=1)
df1
# Out:
#       id  Leader 1 Location ID       Agent Name         Leader Name  Location
# 0      4         1         ABC    Garnam, Fleur      Howroyd, Kylie  Margaree
# 1     10         1         ABC  Beaver, Leanora      Howroyd, Kylie  Margaree
# 2     11         1         ABC  Cranke, Zabrina      Howroyd, Kylie  Margaree
# 3     12         1         ABC  Matysiak, Berny      Howroyd, Kylie  Margaree
# 4     22         1         ABC    Wyrall, Grace      Howroyd, Kylie  Margaree
# ..   ...       ...         ...              ...                 ...       ...
# 130   86         9         JKL   Longmate, Kiel  Waterfall, Octavia     Digby
# 131   88         9         JKL  Maltman, Fredek  Waterfall, Octavia     Digby
# 132  104         9         JKL     Beer, Bendix  Waterfall, Octavia     Digby
# 133  122         9         JKL    Frunks, Fanya  Waterfall, Octavia     Digby
# 134  126         9         JKL   Blizard, Ringo  Waterfall, Octavia     Digby
#
# [135 rows x 6 columns]

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month Start Date  24 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 320.0 bytes

# %%
date = date.loc[date['Month Start Date']<'2022-01-01']
date
# Out:
#    Month Start Date
# 0        2021-01-01
# 1        2021-02-01
# 2        2021-03-01
# 3        2021-04-01
# 4        2021-05-01
# 5        2021-06-01
# 6        2021-07-01
# 7        2021-08-01
# 8        2021-09-01
# 9        2021-10-01
# 10       2021-11-01
# 11       2021-12-01

# %%
df1['key'] = 1
date['key'] = 1
df1 = pd.merge(df1, date, on = 'key', how = 'outer')
df1
# Out:
#        id  Leader 1 Location ID      Agent Name         Leader Name  Location  \
# 0       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 1       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 2       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 3       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 4       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# ...   ...       ...         ...             ...                 ...       ...
# 1615  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1616  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1617  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1618  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1619  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
#
#       key Month Start Date
# ...

# %%
del df1['key']
df1
# Out:
#        id  Leader 1 Location ID      Agent Name         Leader Name  Location  \
# 0       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 1       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 2       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 3       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 4       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# ...   ...       ...         ...             ...                 ...       ...
# 1615  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1616  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1617  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1618  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1619  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
#
#      Month Start Date
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1620 entries, 0 to 1619
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1620 non-null   int64
#  1   Leader 1          1620 non-null   int64
#  2   Location ID       1620 non-null   object
#  3   Agent Name        1620 non-null   object
#  4   Leader Name       1620 non-null   object
#  5   Location          1620 non-null   object
#  6   Month Start Date  1620 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 101.2+ KB

# %%
df2 = pd.read_excel('MetricData2021.xlsx', sheet_name= None)
df2
# Out:
# {'Jan':      AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
#  0          1            477                  18             459
#  1          2            440                   9             431
#  2          3            514                   1             513
#  3          4            445                   2             443
#  4          5            399                   3             396
#  ..       ...            ...                 ...             ...
#  104      105            498                  21             477
#  105      106            439                  20             419
#  106      107            736                   3             733
#  107      108            578                  17             561
#  108      109            839                  25             814
#
#       Total Duration  Sentiment
#  0              2385         48
#  1              5720        -15
#  2              2056        -25
#  3              7565        -53
# ...

# %%
i = 1
for key in df2.keys():
    df2[key]['month'] = '2021-{}-01'.format(i)
    i += 1
df2
# Out:
# {'Jan':      AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
#  0          1            477                  18             459
#  1          2            440                   9             431
#  2          3            514                   1             513
#  3          4            445                   2             443
#  4          5            399                   3             396
#  ..       ...            ...                 ...             ...
#  104      105            498                  21             477
#  105      106            439                  20             419
#  106      107            736                   3             733
#  107      108            578                  17             561
#  108      109            839                  25             814
#
#       Total Duration  Sentiment      month
#  0              2385         48  2021-1-01
#  1              5720        -15  2021-1-01
#  2              2056        -25  2021-1-01
# ...

# %%
df2['Dec'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AgentID         135 non-null    int64
#  1   Offered         135 non-null    int64
#  2   Not Answered    135 non-null    int64
#  3   Answered        135 non-null    int64
#  4   Total Duration  135 non-null    int64
#  5   Sentiment       135 non-null    int64
#  6   Transfers       135 non-null    int64
#  7   month           135 non-null    object
# dtypes: int64(7), object(1)
# memory usage: 8.6+ KB

# %%
df2 = pd.concat(df2, ignore_index = True)
df2
# Out:
#       AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
# 0           1          477.0                18.0           459.0
# 1           2          440.0                 9.0           431.0
# 2           3          514.0                 1.0           513.0
# 3           4          445.0                 2.0           443.0
# 4           5          399.0                 3.0           396.0
# ...       ...            ...                 ...             ...
# 1511      131            NaN                 NaN             NaN
# 1512      132            NaN                 NaN             NaN
# 1513      133            NaN                 NaN             NaN
# 1514      134            NaN                 NaN             NaN
# 1515      135            NaN                 NaN             NaN
#
#       Total Duration  Sentiment       month  Offered  Not Answered  Answered  \
# 0               2385         48   2021-1-01      NaN           NaN       NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516 entries, 0 to 1515
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AgentID             1516 non-null   int64
#  1   Calls Offered       436 non-null    float64
#  2   Calls Not Answered  436 non-null    float64
#  3   Calls Answered      436 non-null    float64
#  4   Total Duration      1516 non-null   int64
#  5   Sentiment           1516 non-null   int64
#  6   month               1516 non-null   object
#  7   Offered             1080 non-null   float64
#  8   Not Answered        1080 non-null   float64
#  9   Answered            1080 non-null   float64
#  10  Transfers           1080 non-null   float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 130.4+ KB

# %%
df3 = df2.copy()
df3
# Out:
#       AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
# 0           1          477.0                18.0           459.0
# 1           2          440.0                 9.0           431.0
# 2           3          514.0                 1.0           513.0
# 3           4          445.0                 2.0           443.0
# 4           5          399.0                 3.0           396.0
# ...       ...            ...                 ...             ...
# 1511      131            NaN                 NaN             NaN
# 1512      132            NaN                 NaN             NaN
# 1513      133            NaN                 NaN             NaN
# 1514      134            NaN                 NaN             NaN
# 1515      135            NaN                 NaN             NaN
#
#       Total Duration  Sentiment       month  Offered  Not Answered  Answered  \
# 0               2385         48   2021-1-01      NaN           NaN       NaN
# ...

# %%
df3 = df3.replace(np.NaN, 0)
df3
# Out:
#       AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
# 0           1          477.0                18.0           459.0
# 1           2          440.0                 9.0           431.0
# 2           3          514.0                 1.0           513.0
# 3           4          445.0                 2.0           443.0
# 4           5          399.0                 3.0           396.0
# ...       ...            ...                 ...             ...
# 1511      131            0.0                 0.0             0.0
# 1512      132            0.0                 0.0             0.0
# 1513      133            0.0                 0.0             0.0
# 1514      134            0.0                 0.0             0.0
# 1515      135            0.0                 0.0             0.0
#
#       Total Duration  Sentiment       month  Offered  Not Answered  Answered  \
# 0               2385         48   2021-1-01      0.0           0.0       0.0
# ...

# %%
df3['Calls Answered'] = df3['Calls Answered'] + df3['Answered']
df3['Calls Offered'] = df3['Calls Offered'] + df3['Offered']
df3['Calls Not Answered'] = df3['Calls Not Answered'] + df3['Not Answered']
df3
# Out:
#       AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
# 0           1          477.0                18.0           459.0
# 1           2          440.0                 9.0           431.0
# 2           3          514.0                 1.0           513.0
# 3           4          445.0                 2.0           443.0
# 4           5          399.0                 3.0           396.0
# ...       ...            ...                 ...             ...
# 1511      131          989.0                81.0           908.0
# 1512      132          939.0                58.0           881.0
# 1513      133          723.0                29.0           694.0
# 1514      134         1001.0                36.0           965.0
# 1515      135          565.0                59.0           506.0
#
#       Total Duration  Sentiment       month  Offered  Not Answered  Answered  \
# 0               2385         48   2021-1-01      0.0           0.0       0.0
# ...

# %%
df3 = df3.drop(columns= ['Offered', 'Not Answered', 'Answered'], axis=1)
df3
# Out:
#       AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
# 0           1          477.0                18.0           459.0
# 1           2          440.0                 9.0           431.0
# 2           3          514.0                 1.0           513.0
# 3           4          445.0                 2.0           443.0
# 4           5          399.0                 3.0           396.0
# ...       ...            ...                 ...             ...
# 1511      131          989.0                81.0           908.0
# 1512      132          939.0                58.0           881.0
# 1513      133          723.0                29.0           694.0
# 1514      134         1001.0                36.0           965.0
# 1515      135          565.0                59.0           506.0
#
#       Total Duration  Sentiment       month  Transfers
# 0               2385         48   2021-1-01        0.0
# 1               5720        -15   2021-1-01        0.0
# ...

# %%
df3['month'] = pd.to_datetime(df3['month'])
df3
# Out:
#       AgentID  Calls Offered  Calls Not Answered  Calls Answered  \
# 0           1          477.0                18.0           459.0
# 1           2          440.0                 9.0           431.0
# 2           3          514.0                 1.0           513.0
# 3           4          445.0                 2.0           443.0
# 4           5          399.0                 3.0           396.0
# ...       ...            ...                 ...             ...
# 1511      131          989.0                81.0           908.0
# 1512      132          939.0                58.0           881.0
# 1513      133          723.0                29.0           694.0
# 1514      134         1001.0                36.0           965.0
# 1515      135          565.0                59.0           506.0
#
#       Total Duration  Sentiment      month  Transfers
# 0               2385         48 2021-01-01        0.0
# 1               5720        -15 2021-01-01        0.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516 entries, 0 to 1515
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AgentID             1516 non-null   int64
#  1   Calls Offered       1516 non-null   float64
#  2   Calls Not Answered  1516 non-null   float64
#  3   Calls Answered      1516 non-null   float64
#  4   Total Duration      1516 non-null   int64
#  5   Sentiment           1516 non-null   int64
#  6   month               1516 non-null   datetime64[ns]
#  7   Transfers           1516 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3)
# memory usage: 94.9 KB

# %%
df = pd.merge(df1, df3, left_on = ['Month Start Date','id'], right_on = ['month','AgentID'], how = 'outer')
df
# Out:
#        id  Leader 1 Location ID      Agent Name         Leader Name  Location  \
# 0       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 1       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 2       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 3       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# 4       4         1         ABC   Garnam, Fleur      Howroyd, Kylie  Margaree
# ...   ...       ...         ...             ...                 ...       ...
# 1615  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1616  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1617  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1618  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
# 1619  126         9         JKL  Blizard, Ringo  Waterfall, Octavia     Digby
#
# ...

# %%
df= df[['id','Agent Name','Leader 1','Leader Name','Month Start Date','Location','Calls Answered','Calls Not Answered','Calls Offered','Total Duration','Transfers','Sentiment']]

# %%
df
# Out:
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# 1615  126  Blizard, Ringo         9  Waterfall, Octavia       2021-08-01
# 1616  126  Blizard, Ringo         9  Waterfall, Octavia       2021-09-01
# 1617  126  Blizard, Ringo         9  Waterfall, Octavia       2021-10-01
# 1618  126  Blizard, Ringo         9  Waterfall, Octavia       2021-11-01
# 1619  126  Blizard, Ringo         9  Waterfall, Octavia       2021-12-01
#
#       Location  Calls Answered  Calls Not Answered  Calls Offered  \
# ...

# %%
df.insert(8, 'Not Answered Rate', df['Calls Not Answered']/(df['Calls Offered']))
df
# Out:
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# 1615  126  Blizard, Ringo         9  Waterfall, Octavia       2021-08-01
# 1616  126  Blizard, Ringo         9  Waterfall, Octavia       2021-09-01
# 1617  126  Blizard, Ringo         9  Waterfall, Octavia       2021-10-01
# 1618  126  Blizard, Ringo         9  Waterfall, Octavia       2021-11-01
# 1619  126  Blizard, Ringo         9  Waterfall, Octavia       2021-12-01
#
#       Location  Calls Answered  Calls Not Answered  Not Answered Rate  \
# ...

# %%
df.insert(9, 'Met Not Answered Rate', df['Not Answered Rate']<5/100)
df
# Out:
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# 1615  126  Blizard, Ringo         9  Waterfall, Octavia       2021-08-01
# 1616  126  Blizard, Ringo         9  Waterfall, Octavia       2021-09-01
# 1617  126  Blizard, Ringo         9  Waterfall, Octavia       2021-10-01
# 1618  126  Blizard, Ringo         9  Waterfall, Octavia       2021-11-01
# 1619  126  Blizard, Ringo         9  Waterfall, Octavia       2021-12-01
#
#       Location  Calls Answered  Calls Not Answered  Not Answered Rate  \
# ...

# %%
df.insert(10, 'Not Answered Percent < 5', 5)
df
# Out:
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# 1615  126  Blizard, Ringo         9  Waterfall, Octavia       2021-08-01
# 1616  126  Blizard, Ringo         9  Waterfall, Octavia       2021-09-01
# 1617  126  Blizard, Ringo         9  Waterfall, Octavia       2021-10-01
# 1618  126  Blizard, Ringo         9  Waterfall, Octavia       2021-11-01
# 1619  126  Blizard, Ringo         9  Waterfall, Octavia       2021-12-01
#
#       Location  Calls Answered  Calls Not Answered  Not Answered Rate  \
# ...

# %%
df.insert(13, 'Agent Avg Duration', df['Total Duration']/(df['Calls Offered']))
df
# Out:
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# 1615  126  Blizard, Ringo         9  Waterfall, Octavia       2021-08-01
# 1616  126  Blizard, Ringo         9  Waterfall, Octavia       2021-09-01
# 1617  126  Blizard, Ringo         9  Waterfall, Octavia       2021-10-01
# 1618  126  Blizard, Ringo         9  Waterfall, Octavia       2021-11-01
# 1619  126  Blizard, Ringo         9  Waterfall, Octavia       2021-12-01
#
#       Location  Calls Answered  Calls Not Answered  Not Answered Rate  \
# ...

# %%
df['Sentiment Score >= 0'] =0
df
# Out:
# /var/folders/dj/y93b_3q50zsdp08ywrx7w_l40000gn/T/ipykernel_28734/670971151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sentiment Score >= 0'] =0
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# ...

# %%
df['Met Sentiment Goal'] = (df['Sentiment']>=0)
df
# Out:
# /var/folders/dj/y93b_3q50zsdp08ywrx7w_l40000gn/T/ipykernel_28734/1551479343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Met Sentiment Goal'] = (df['Sentiment']>=0)
#        id      Agent Name  Leader 1         Leader Name Month Start Date  \
# 0       4   Garnam, Fleur         1      Howroyd, Kylie       2021-01-01
# 1       4   Garnam, Fleur         1      Howroyd, Kylie       2021-02-01
# 2       4   Garnam, Fleur         1      Howroyd, Kylie       2021-03-01
# 3       4   Garnam, Fleur         1      Howroyd, Kylie       2021-04-01
# 4       4   Garnam, Fleur         1      Howroyd, Kylie       2021-05-01
# ...   ...             ...       ...                 ...              ...
# ...

# %%
df.to_excel('week7.xlsx')
