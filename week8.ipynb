# %%
import pandas as pd
import numpy as np

stat = pd.read_excel('input_pkmn_stats_and_evolutions.xlsx', sheet_name = 'pkmn_stats')
evo = pd.read_excel('input_pkmn_stats_and_evolutions.xlsx', sheet_name = 'pkmn_evolutions')

# %%
stat
# Out:
#             name  pokedex_number  gen_introduced   hp  attack  defense  \
# 0      Bulbasaur               1               1   45      49       49
# 1        Ivysaur               2               1   60      62       63
# 2       Venusaur               3               1   80      82       83
# 3     Charmander               4               1   39      52       43
# 4     Charmeleon               5               1   58      64       58
# ..           ...             ...             ...  ...     ...      ...
# 900     Ursaluna             901               8  130     140      105
# 901  Basculegion             902               8  120     112       65
# 902     Sneasler             903               8   80     130       60
# 903     Overqwil             904               8   85     115       95
# 904     Enamorus             905               8   74     115       70
#
#      special_attack  special_defense  speed  height  weight evolves_from
# ...

# %%
evo
# Out:
#         Stage_1     Stage_2     Stage_3
# 0     Bulbasaur     Ivysaur    Venusaur
# 1    Charmander  Charmeleon   Charizard
# 2      Squirtle   Wartortle   Blastoise
# 3      Caterpie     Metapod  Butterfree
# 4        Weedle      Kakuna    Beedrill
# ..          ...         ...         ...
# 488   Regidrago         NaN         NaN
# 489   Glastrier         NaN         NaN
# 490   Spectrier         NaN         NaN
# 491     Calyrex         NaN         NaN
# 492    Enamorus         NaN         NaN
#
# [493 rows x 3 columns]

# %%
stat = stat.drop(columns = ['height', 'weight', 'evolves_from'])
stat
# Out:
#             name  pokedex_number  gen_introduced   hp  attack  defense  \
# 0      Bulbasaur               1               1   45      49       49
# 1        Ivysaur               2               1   60      62       63
# 2       Venusaur               3               1   80      82       83
# 3     Charmander               4               1   39      52       43
# 4     Charmeleon               5               1   58      64       58
# ..           ...             ...             ...  ...     ...      ...
# 900     Ursaluna             901               8  130     140      105
# 901  Basculegion             902               8  120     112       65
# 902     Sneasler             903               8   80     130       60
# 903     Overqwil             904               8   85     115       95
# 904     Enamorus             905               8   74     115       70
#
#      special_attack  special_defense  speed
# 0                65               65     45
# ...

# %%
stat2 = pd.melt(stat, id_vars = ['name','pokedex_number','gen_introduced'],var_name = 'combat_factors', value_name = 'values')
stat2
# Out:
#              name  pokedex_number  gen_introduced combat_factors  values
# 0       Bulbasaur               1               1             hp      45
# 1         Ivysaur               2               1             hp      60
# 2        Venusaur               3               1             hp      80
# 3      Charmander               4               1             hp      39
# 4      Charmeleon               5               1             hp      58
# ...           ...             ...             ...            ...     ...
# 5425     Ursaluna             901               8          speed      50
# 5426  Basculegion             902               8          speed      78
# 5427     Sneasler             903               8          speed     120
# 5428     Overqwil             904               8          speed      85
# 5429     Enamorus             905               8          speed     106
#
# [5430 rows x 5 columns]

# %%
stat2 = stat2.sort_values(by='pokedex_number')
stat2
# Out:
#            name  pokedex_number  gen_introduced   combat_factors  values
# 0     Bulbasaur               1               1               hp      45
# 1810  Bulbasaur               1               1          defense      49
# 4525  Bulbasaur               1               1            speed      45
# 3620  Bulbasaur               1               1  special_defense      65
# 2715  Bulbasaur               1               1   special_attack      65
# ...         ...             ...             ...              ...     ...
# 3619   Enamorus             905               8   special_attack     135
# 1809   Enamorus             905               8           attack     115
# 904    Enamorus             905               8               hp      74
# 4524   Enamorus             905               8  special_defense      80
# 5429   Enamorus             905               8            speed     106
#
# [5430 rows x 5 columns]

# %%
stat2 =stat2.reset_index(drop=True)
stat2
# Out:
#            name  pokedex_number  gen_introduced   combat_factors  values
# 0     Bulbasaur               1               1               hp      45
# 1     Bulbasaur               1               1          defense      49
# 2     Bulbasaur               1               1            speed      45
# 3     Bulbasaur               1               1  special_defense      65
# 4     Bulbasaur               1               1   special_attack      65
# ...         ...             ...             ...              ...     ...
# 5425   Enamorus             905               8   special_attack     135
# 5426   Enamorus             905               8           attack     115
# 5427   Enamorus             905               8               hp      74
# 5428   Enamorus             905               8  special_defense      80
# 5429   Enamorus             905               8            speed     106
#
# [5430 rows x 5 columns]

# %%
stat3 = stat2.groupby(['name','pokedex_number','gen_introduced']).sum()
stat3
# Out:
#                                                 values
# name             pokedex_number gen_introduced
# Abomasnow        460            4                  494
# Abra             63             1                  310
# Absol            359            3                  465
# Accelgor         617            5                  495
# Aegislash Shield 681            6                  500
# ...                                                ...
# Zoroark          571            5                  510
# Zorua            570            5                  330
# Zubat            41             1                  245
# Zweilous         634            5                  420
# Zygarde          718            6                  600
#
# [905 rows x 1 columns]

# %%
stat3 = stat3.sort_values(by = 'pokedex_number')
stat3
# Out:
#                                            values
# name        pokedex_number gen_introduced
# Bulbasaur   1              1                  318
# Ivysaur     2              1                  405
# Venusaur    3              1                  525
# Charmander  4              1                  309
# Charmeleon  5              1                  405
# ...                                           ...
# Ursaluna    901            8                  550
# Basculegion 902            8                  530
# Sneasler    903            8                  510
# Overqwil    904            8                  510
# Enamorus    905            8                  580
#
# [905 rows x 1 columns]

# %%
stat3.reset_index(inplace = True)
stat3
# Out:
#             name  pokedex_number  gen_introduced  values
# 0      Bulbasaur               1               1     318
# 1        Ivysaur               2               1     405
# 2       Venusaur               3               1     525
# 3     Charmander               4               1     309
# 4     Charmeleon               5               1     405
# ..           ...             ...             ...     ...
# 900     Ursaluna             901               8     550
# 901  Basculegion             902               8     530
# 902     Sneasler             903               8     510
# 903     Overqwil             904               8     510
# 904     Enamorus             905               8     580
#
# [905 rows x 4 columns]

# %%
evo
# Out:
#         Stage_1     Stage_2     Stage_3
# 0     Bulbasaur     Ivysaur    Venusaur
# 1    Charmander  Charmeleon   Charizard
# 2      Squirtle   Wartortle   Blastoise
# 3      Caterpie     Metapod  Butterfree
# 4        Weedle      Kakuna    Beedrill
# ..          ...         ...         ...
# 488   Regidrago         NaN         NaN
# 489   Glastrier         NaN         NaN
# 490   Spectrier         NaN         NaN
# 491     Calyrex         NaN         NaN
# 492    Enamorus         NaN         NaN
#
# [493 rows x 3 columns]

# %%
df = pd.merge(evo, stat3, left_on = 'Stage_1', right_on = 'name', how='left')
df
# Out:
#         Stage_1     Stage_2     Stage_3        name  pokedex_number  \
# 0     Bulbasaur     Ivysaur    Venusaur   Bulbasaur               1
# 1    Charmander  Charmeleon   Charizard  Charmander               4
# 2      Squirtle   Wartortle   Blastoise    Squirtle               7
# 3      Caterpie     Metapod  Butterfree    Caterpie              10
# 4        Weedle      Kakuna    Beedrill      Weedle              13
# ..          ...         ...         ...         ...             ...
# 488   Regidrago         NaN         NaN   Regidrago             895
# 489   Glastrier         NaN         NaN   Glastrier             896
# 490   Spectrier         NaN         NaN   Spectrier             897
# 491     Calyrex         NaN         NaN     Calyrex             898
# 492    Enamorus         NaN         NaN    Enamorus             905
#
#      gen_introduced  values
# 0                 1     318
# 1                 1     309
# 2                 1     314
# 3                 1     195
# ...

# %%
df.rename(columns={'values':'initial_combat_power'}, inplace = True)
df
# Out:
#         Stage_1     Stage_2     Stage_3        name  pokedex_number  \
# 0     Bulbasaur     Ivysaur    Venusaur   Bulbasaur               1
# 1    Charmander  Charmeleon   Charizard  Charmander               4
# 2      Squirtle   Wartortle   Blastoise    Squirtle               7
# 3      Caterpie     Metapod  Butterfree    Caterpie              10
# 4        Weedle      Kakuna    Beedrill      Weedle              13
# ..          ...         ...         ...         ...             ...
# 488   Regidrago         NaN         NaN   Regidrago             895
# 489   Glastrier         NaN         NaN   Glastrier             896
# 490   Spectrier         NaN         NaN   Spectrier             897
# 491     Calyrex         NaN         NaN     Calyrex             898
# 492    Enamorus         NaN         NaN    Enamorus             905
#
#      gen_introduced  initial_combat_power
# 0                 1                   318
# 1                 1                   309
# ...

# %%
df = df.drop(columns='name')
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 488   Regidrago         NaN         NaN             895               8
# 489   Glastrier         NaN         NaN             896               8
# 490   Spectrier         NaN         NaN             897               8
# 491     Calyrex         NaN         NaN             898               8
# 492    Enamorus         NaN         NaN             905               8
#
#      initial_combat_power
# 0                     318
# 1                     309
# ...

# %%
df = df.dropna(subset=['Stage_2'])
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 467     Milcery    Alcremie         NaN             868               8
# 470        Snom    Frosmoth         NaN             872               8
# 475      Cufant  Copperajah         NaN             878               8
# 481      Dreepy    Drakloak   Dragapult             885               8
# 485       Kubfu     Urshifu         NaN             891               8
#
#      initial_combat_power
# 0                     318
# 1                     309
# ...

# %%
fin = stat3[['name','values']]
fin
# Out:
#             name  values
# 0      Bulbasaur     318
# 1        Ivysaur     405
# 2       Venusaur     525
# 3     Charmander     309
# 4     Charmeleon     405
# ..           ...     ...
# 900     Ursaluna     550
# 901  Basculegion     530
# 902     Sneasler     510
# 903     Overqwil     510
# 904     Enamorus     580
#
# [905 rows x 2 columns]

# %%
df = pd.merge(df, fin, left_on='Stage_2', right_on='name', how='left')
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 325     Milcery    Alcremie         NaN             868               8
# 326        Snom    Frosmoth         NaN             872               8
# 327      Cufant  Copperajah         NaN             878               8
# 328      Dreepy    Drakloak   Dragapult             885               8
# 329       Kubfu     Urshifu         NaN             891               8
#
#      initial_combat_power        name  values
# 0                     318     Ivysaur     405
# ...

# %%
df = pd.merge(df, fin, left_on='Stage_3', right_on='name', how='left')
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 325     Milcery    Alcremie         NaN             868               8
# 326        Snom    Frosmoth         NaN             872               8
# 327      Cufant  Copperajah         NaN             878               8
# 328      Dreepy    Drakloak   Dragapult             885               8
# 329       Kubfu     Urshifu         NaN             891               8
#
#      initial_combat_power      name_x  values_x      name_y  values_y
# ...

# %%
df['final_combat_power'] = df['values_y']
df.loc[pd.isnull(df['final_combat_power']),'final_combat_power']=df['values_x']
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 325     Milcery    Alcremie         NaN             868               8
# 326        Snom    Frosmoth         NaN             872               8
# 327      Cufant  Copperajah         NaN             878               8
# 328      Dreepy    Drakloak   Dragapult             885               8
# 329       Kubfu     Urshifu         NaN             891               8
#
#      initial_combat_power      name_x  values_x      name_y  values_y  \
# ...

# %%
df = df.drop(columns=['name_x','values_x','name_y','values_y'])
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 325     Milcery    Alcremie         NaN             868               8
# 326        Snom    Frosmoth         NaN             872               8
# 327      Cufant  Copperajah         NaN             878               8
# 328      Dreepy    Drakloak   Dragapult             885               8
# 329       Kubfu     Urshifu         NaN             891               8
#
#      initial_combat_power  final_combat_power
# 0                     318               525.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 329
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Stage_1               330 non-null    object
#  1   Stage_2               330 non-null    object
#  2   Stage_3               110 non-null    object
#  3   pokedex_number        330 non-null    int64
#  4   gen_introduced        330 non-null    int64
#  5   initial_combat_power  330 non-null    int64
#  6   final_combat_power    330 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 28.7+ KB

# %%
df['final_combat_power'] = df['final_combat_power'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 329
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Stage_1               330 non-null    object
#  1   Stage_2               330 non-null    object
#  2   Stage_3               110 non-null    object
#  3   pokedex_number        330 non-null    int64
#  4   gen_introduced        330 non-null    int64
#  5   initial_combat_power  330 non-null    int64
#  6   final_combat_power    330 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 28.7+ KB

# %%
df['combat_power_increase'] = df['final_combat_power']/df['initial_combat_power']-1
df
# Out:
#         Stage_1     Stage_2     Stage_3  pokedex_number  gen_introduced  \
# 0     Bulbasaur     Ivysaur    Venusaur               1               1
# 1    Charmander  Charmeleon   Charizard               4               1
# 2      Squirtle   Wartortle   Blastoise               7               1
# 3      Caterpie     Metapod  Butterfree              10               1
# 4        Weedle      Kakuna    Beedrill              13               1
# ..          ...         ...         ...             ...             ...
# 325     Milcery    Alcremie         NaN             868               8
# 326        Snom    Frosmoth         NaN             872               8
# 327      Cufant  Copperajah         NaN             878               8
# 328      Dreepy    Drakloak   Dragapult             885               8
# 329       Kubfu     Urshifu         NaN             891               8
#
#      initial_combat_power  final_combat_power  combat_power_increase
# ...

# %%
df.to_csv('Output22_8.csv')
